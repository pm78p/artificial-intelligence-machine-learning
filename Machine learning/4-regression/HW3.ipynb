# %% [markdown]
# Consider the y = w1x + w0 linear regression problem. Assume we’ve got n train data , We are looking to minimize the following cost function:
# 1 nPn i=1 (y(i) −w(1)x(i) −w(0))2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import random
import math
import itertools

# %%
df = pd.read_csv("./Datasets/FirstDataset.txt", delimiter="\t", names=['x','y'])
df.head(15)
# Out:
#            x         y
# 0  -2.996219  1.424365
# 1  -2.987382  0.372525
# 2  -2.980072 -0.142835
# 3  -2.968503 -0.296066
# 4  -2.966581 -0.106994
# 5  -2.964482  0.466139
# 6  -2.964113 -0.495662
# 7  -2.962814  0.333751
# 8  -2.951097  0.154589
# 9  -2.932613 -0.643678
# 10 -2.920537 -0.425649
# 11 -2.914211 -1.074975
# 12 -2.913999 -1.744474
# 13 -2.903551 -1.693660
# 14 -2.898431 -1.336128

# %%
X, Y = df["x"], df["y"].to_numpy().reshape((-1, 1))
X = np.column_stack([X, np.ones(len(Y))])

def gd(W, X, Y, lr=0.01, itr=5000):
    for _ in range(itr):
        W = W - (1/len(X))*lr*(X.T.dot((X.dot(W)-Y)))
    return W

def sgd(X, Y, lr=0.01, itr=5000, k=0.05):
    W = np.random.randn(2, 1)
    for i in range(itr):
        sample_num = random.sample([i for i in range(len(X))], random.randint(0, len(X)))
        sampleX, sampleY = X[sample_num,], Y[sample_num,]
        W = W - (1 / len(X)) * lr * np.dot(sampleX.T, np.dot(sampleX, W) - sampleY)
    return W

def cf(X, Y):
    return np.dot( np.linalg.inv( np.dot(X.T, X)), np.dot(X.T,Y))

# %% [markdown]
# we will write a python code that compute closed form solution for w0 and w1 on the ﬁrst dataset by using gradient descent and stochastic gradient descent , then compare these two together.

# %%
W = np.random.randn(2, 1)
Wgd = gd(W, X, Y)
WSGD = sgd(X,Y)
WCF = cf(X, Y)
print(Wgd)
print(WSGD)
# Out:
# [[ 0.91488253]
#  [-2.95462259]]
# [[ 1.01543079]
#  [-2.75747833]]

# %% [markdown]
# #### As we can observe the diffrence between GD and SGD is about 0.3 for each weight

# %%
df2 = pd.read_csv("./Datasets/SecondDataset.txt", delimiter="\t", names=['x0','x1','x2','y'])
df2.head(15)
# Out:
#          x0     x1     x2     y
# 0   0.00632  0.538  6.575  24.0
# 1   0.02731  0.469  6.421  21.6
# 2   0.02729  0.469  7.185  34.7
# 3   0.03237  0.458  6.998  33.4
# 4   0.06905  0.458  7.147  36.2
# 5   0.02985  0.458  6.430  28.7
# 6   0.08829  0.524  6.012  22.9
# 7   0.14455  0.524  6.172  27.1
# 8   0.21124  0.524  5.631  16.5
# 9   0.17004  0.524  6.004  18.9
# 10  0.22489  0.524  6.377  15.0
# 11  0.11747  0.524  6.009  18.9
# 12  0.09378  0.524  5.889  21.7
# 13  0.62976  0.538  5.949  20.4
# 14  0.63796  0.538  6.096  18.2

# %% [markdown]
# we will split second dataset into train and test data , Then Train a regression model on train data that satisfy following problems. (ﬁrst 3 columns are features and the last one is the target)

# %%
X = df2[["x0", "x1", "x2"]].to_numpy()
X = np.insert(X, 0, np.ones(X.shape[0]), axis=1)
Y = df2['y'].to_numpy()
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, shuffle= False)

# %%
def MSE(X,Y,W):
    return 1/len(X) * np.sum(np.square(Y-np.dot(W,X.T)))

# %%
def linear_reg(X, Y, iterations = 20000, alpha = 0.0001):
    w = np.zeros(X.shape[1] )
    for i in range(iterations):
        w = w + alpha * 2/(len(X)) * np.dot(Y - np.dot(w,X.T),X)
    return w

# %% [markdown]
# we would like to train a 1st order regression model with SSE as cost function. Then report the w vector and error on train and test data.

# %%
w1 = linear_reg(X_train, Y_train)
print(MSE(X,Y,w1))
# Out:
# 47.21188185154445

# %%
def third_reg(X, Y):
    w = np.dot( np.dot( np.linalg.inv( np.dot( X.T, X)), X.T), Y)
    return w

# %% [markdown]
# here we train a 3rd order regression model with SSE as cost function. Then report the w vector and error on train and test data.

# %%
w3 = third_reg(X_train, Y_train)
print(w3)
print(MSE(X_train, Y_train, w3))
# Out:
# [-16.0980859   -0.19345404 -13.42903707   7.47552658]
# 38.29850482058393

# %%
def third_reg_regu(X, Y, X_test, Y_test, iterations = 20000, alpha= 4e-10):
    err_train, err_test, lambda_list = [], [], []
    listz = np.linspace(-1,20,42)
    X, X_test = itr_make(X, X_test)

    w_list = []
    for i in listz:
        w = np.zeros(X.shape[1])
        slambda = math.exp(i)
        for i in range(iterations):
            w = w + alpha * 2 / len(X) * (np.dot((Y - np.dot(w , X.T)) , X) - slambda * w)
        lambda_list.append(slambda)
        err_train.append(MSE(X,Y,w))
        err_test.append(MSE(X_test,Y_test,w))
        w_list.append(w)
    return (lambda_list, err_train, err_test, w_list)

def itr_make(X, X_test):
    a = list(itertools.combinations_with_replacement(range(X.shape[1]),3))
    X = np.array([X[:, i[0]] * X[:, i[1]] * X[:, i[2]] for i in a]).T
    X_test =  np.array([X_test[:, i[0]] * X_test[:, i[1]] * X_test[:, i[2]] for i in a]).T
    return (X, X_test)

# %%
w3_reg = third_reg_regu(X_train,Y_train,X_test,Y_test)

# %% [markdown]
# and now we train a 3rd order regression model with SSE as cost function and||w||2 as regularization term. Then report the w vector and plot the error for train and test data based on ln(λ).

# %%
print(w3_reg[0])
# Out:
# [0.36787944117144233, 0.6139726608994069, 1.024690118946394, 1.7101573192660526, 2.85416830177539, 4.763466263066106, 7.949990484182254, 13.268142400552419, 22.143875909235756, 36.95703780381613, 61.679475121292526, 102.94000486276288, 171.801795983305, 286.7287323566672, 478.53612640260474, 798.6532161958444, 1332.912866025351, 2224.565897171879, 3712.6908719973353, 6196.298131035919, 10341.31627231978, 17259.147313860252, 28804.666461932855, 48073.56904108966, 80232.41801472109, 133903.95239818524, 223479.09874242608, 372975.6043810696, 622477.9061945205, 1038884.954267483, 1733847.799998998, 2893706.5468245707, 4829453.645896843, 8060120.174749803, 13451943.427721733, 22450630.767207265, 37468996.5471285, 62533909.03828814, 104366012.96995685, 174181733.2509328, 290700730.39038754, 485165195.4097903]

# %%
print(w3_reg[3])
# Out:
# [array([ 2.03471844e-04,  1.61658434e-04,  1.05405069e-04,  1.32274357e-03,
#        -1.85457680e-04,  1.00854577e-04,  9.40973544e-04,  5.67522964e-05,
#         6.79343149e-04,  8.72853773e-03, -5.15115760e-06, -2.05413588e-04,
#        -5.39148280e-04,  6.45452563e-05,  5.82265944e-04,  5.67853129e-03,
#         3.19454870e-05,  3.62062353e-04,  4.45001909e-03,  5.84396388e-02]), array([ 2.03471843e-04,  1.61658434e-04,  1.05405068e-04,  1.32274357e-03,
#        -1.85457676e-04,  1.00854577e-04,  9.40973542e-04,  5.67522962e-05,
#         6.79343146e-04,  8.72853769e-03, -5.15115911e-06, -2.05413585e-04,
#        -5.39148259e-04,  6.45452562e-05,  5.82265942e-04,  5.67853128e-03,
#         3.19454869e-05,  3.62062351e-04,  4.45001907e-03,  5.84396386e-02]), array([ 2.03471842e-04,  1.61658433e-04,  1.05405068e-04,  1.32274356e-03,
#        -1.85457670e-04,  1.00854577e-04,  9.40973539e-04,  5.67522959e-05,
#         6.79343142e-04,  8.72853764e-03, -5.15116163e-06, -2.05413580e-04,
#        -5.39148226e-04,  6.45452559e-05,  5.82265940e-04,  5.67853126e-03,
#         3.19454867e-05,  3.62062349e-04,  4.45001904e-03,  5.84396382e-02]), array([ 2.03471840e-04,  1.61658432e-04,  1.05405067e-04,  1.32274355e-03,
#        -1.85457660e-04,  1.00854576e-04,  9.40973533e-04,  5.67522953e-05,
#         6.79343135e-04,  8.72853755e-03, -5.15116584e-06, -2.05413573e-04,
#        -5.39148169e-04,  6.45452556e-05,  5.82265937e-04,  5.67853123e-03,
#         3.19454863e-05,  3.62062346e-04,  4.45001900e-03,  5.84396376e-02]), array([ 2.03471836e-04,  1.61658430e-04,  1.05405065e-04,  1.32274352e-03,
#        -1.85457644e-04,  1.00854575e-04,  9.40973523e-04,  5.67522943e-05,
#         6.79343124e-04,  8.72853740e-03, -5.15117286e-06, -2.05413560e-04,
#        -5.39148075e-04,  6.45452549e-05,  5.82265931e-04,  5.67853118e-03,
#         3.19454858e-05,  3.62062340e-04,  4.45001892e-03,  5.84396366e-02]), array([ 2.03471831e-04,  1.61658427e-04,  1.05405062e-04,  1.32274349e-03,
#        -1.85457616e-04,  1.00854573e-04,  9.40973507e-04,  5.67522927e-05,
#         6.79343104e-04,  8.72853715e-03, -5.15118458e-06, -2.05413538e-04,
#        -5.39147917e-04,  6.45452538e-05,  5.82265922e-04,  5.67853108e-03,
#         3.19454849e-05,  3.62062330e-04,  4.45001880e-03,  5.84396350e-02]), array([ 2.03471821e-04,  1.61658422e-04,  1.05405057e-04,  1.32274342e-03,
#        -1.85457569e-04,  1.00854570e-04,  9.40973480e-04,  5.67522901e-05,
#         6.79343072e-04,  8.72853674e-03, -5.15120414e-06, -2.05413502e-04,
#        -5.39147655e-04,  6.45452520e-05,  5.82265907e-04,  5.67853093e-03,
#         3.19454835e-05,  3.62062313e-04,  4.45001859e-03,  5.84396322e-02]), array([ 2.03471805e-04,  1.61658414e-04,  1.05405049e-04,  1.32274332e-03,
#        -1.85457491e-04,  1.00854565e-04,  9.40973435e-04,  5.67522857e-05,
#         6.79343019e-04,  8.72853605e-03, -5.15123679e-06, -2.05413442e-04,
#        -5.39147216e-04,  6.45452490e-05,  5.82265881e-04,  5.67853068e-03,
#         3.19454810e-05,  3.62062285e-04,  4.45001824e-03,  5.84396276e-02]), array([ 2.03471778e-04,  1.61658400e-04,  1.05405035e-04,  1.32274314e-03,
#        -1.85457361e-04,  1.00854557e-04,  9.40973360e-04,  5.67522783e-05,
#         6.79342930e-04,  8.72853490e-03, -5.15129127e-06, -2.05413342e-04,
#        -5.39146484e-04,  6.45452440e-05,  5.82265838e-04,  5.67853025e-03,
#         3.19454769e-05,  3.62062238e-04,  4.45001766e-03,  5.84396199e-02]), array([ 2.03471733e-04,  1.61658376e-04,  1.05405012e-04,  1.32274285e-03,
#        -1.85457145e-04,  1.00854543e-04,  9.40973235e-04,  5.67522660e-05,
#         6.79342781e-04,  8.72853297e-03, -5.15138220e-06, -2.05413174e-04,
#        -5.39145263e-04,  6.45452357e-05,  5.82265766e-04,  5.67852955e-03,
#         3.19454700e-05,  3.62062159e-04,  4.45001669e-03,  5.84396070e-02]), array([ 2.03471657e-04,  1.61658337e-04,  1.05404973e-04,  1.32274236e-03,
#        -1.85456783e-04,  1.00854521e-04,  9.40973026e-04,  5.67522454e-05,
#         6.79342533e-04,  8.72852976e-03, -5.15153396e-06, -2.05412895e-04,
#        -5.39143225e-04,  6.45452217e-05,  5.82265646e-04,  5.67852836e-03,
#         3.19454586e-05,  3.62062029e-04,  4.45001507e-03,  5.84395855e-02]), array([ 2.03471532e-04,  1.61658272e-04,  1.05404908e-04,  1.32274155e-03,
#        -1.85456180e-04,  1.00854482e-04,  9.40972677e-04,  5.67522110e-05,
#         6.79342119e-04,  8.72852439e-03, -5.15178723e-06, -2.05412429e-04,
#        -5.39139823e-04,  6.45451984e-05,  5.82265446e-04,  5.67852639e-03,
#         3.19454395e-05,  3.62061811e-04,  4.45001236e-03,  5.84395497e-02]), array([ 2.03471322e-04,  1.61658164e-04,  1.05404801e-04,  1.32274019e-03,
#        -1.85455173e-04,  1.00854418e-04,  9.40972094e-04,  5.67521537e-05,
#         6.79341428e-04,  8.72851544e-03, -5.15220993e-06, -2.05411651e-04,
#        -5.39134146e-04,  6.45451596e-05,  5.82265112e-04,  5.67852310e-03,
#         3.19454076e-05,  3.62061447e-04,  4.45000785e-03,  5.84394899e-02]), array([ 2.03470972e-04,  1.61657983e-04,  1.05404621e-04,  1.32273792e-03,
#        -1.85453492e-04,  1.00854312e-04,  9.40971122e-04,  5.67520581e-05,
#         6.79340275e-04,  8.72850050e-03, -5.15291539e-06, -2.05410353e-04,
#        -5.39124670e-04,  6.45450947e-05,  5.82264555e-04,  5.67851761e-03,
#         3.19453543e-05,  3.62060840e-04,  4.45000032e-03,  5.84393901e-02]), array([ 2.03470388e-04,  1.61657680e-04,  1.05404322e-04,  1.32273413e-03,
#        -1.85450687e-04,  1.00854134e-04,  9.40969499e-04,  5.67518984e-05,
#         6.79338350e-04,  8.72847557e-03, -5.15409277e-06, -2.05408187e-04,
#        -5.39108857e-04,  6.45449864e-05,  5.82263624e-04,  5.67850845e-03,
#         3.19452655e-05,  3.62059826e-04,  4.44998774e-03,  5.84392235e-02]), array([ 2.03469413e-04,  1.61657176e-04,  1.05403821e-04,  1.32272781e-03,
#        -1.85446006e-04,  1.00853837e-04,  9.40966791e-04,  5.67516320e-05,
#         6.79335137e-04,  8.72843395e-03, -5.15605773e-06, -2.05404571e-04,
#        -5.39082465e-04,  6.45448058e-05,  5.82262072e-04,  5.67849315e-03,
#         3.19451173e-05,  3.62058134e-04,  4.44996676e-03,  5.84389454e-02]), array([ 2.03467786e-04,  1.61656334e-04,  1.05402986e-04,  1.32271726e-03,
#        -1.85438193e-04,  1.00853341e-04,  9.40962271e-04,  5.67511874e-05,
#         6.79329776e-04,  8.72836450e-03, -5.15933713e-06, -2.05398536e-04,
#        -5.39038419e-04,  6.45445042e-05,  5.82259481e-04,  5.67846762e-03,
#         3.19448698e-05,  3.62055311e-04,  4.44993174e-03,  5.84384813e-02]), array([ 2.03465071e-04,  1.61654929e-04,  1.05401593e-04,  1.32269966e-03,
#        -1.85425154e-04,  1.00852513e-04,  9.40954728e-04,  5.67504453e-05,
#         6.79320828e-04,  8.72824859e-03, -5.16481015e-06, -2.05388465e-04,
#        -5.38964909e-04,  6.45440010e-05,  5.82255156e-04,  5.67842501e-03,
#         3.19444569e-05,  3.62050600e-04,  4.44987330e-03,  5.84377069e-02]), array([ 2.03460539e-04,  1.61652583e-04,  1.05399268e-04,  1.32267028e-03,
#        -1.85403393e-04,  1.00851133e-04,  9.40942139e-04,  5.67492069e-05,
#         6.79305894e-04,  8.72805515e-03, -5.17394405e-06, -2.05371657e-04,
#        -5.38842229e-04,  6.45431612e-05,  5.82247939e-04,  5.67835391e-03,
#         3.19437678e-05,  3.62042736e-04,  4.44977577e-03,  5.84364143e-02]), array([ 2.03452977e-04,  1.61648669e-04,  1.05395387e-04,  1.32262125e-03,
#        -1.85367078e-04,  1.00848828e-04,  9.40921129e-04,  5.67471401e-05,
#         6.79280972e-04,  8.72773232e-03, -5.18918718e-06, -2.05343607e-04,
#        -5.38637493e-04,  6.45417596e-05,  5.82235894e-04,  5.67823524e-03,
#         3.19426177e-05,  3.62029614e-04,  4.44961299e-03,  5.84342572e-02]), array([ 2.03440356e-04,  1.61642138e-04,  1.05388911e-04,  1.32253942e-03,
#        -1.85306474e-04,  1.00844982e-04,  9.40886066e-04,  5.67436909e-05,
#         6.79239382e-04,  8.72719358e-03, -5.21462472e-06, -2.05296797e-04,
#        -5.38295832e-04,  6.45394205e-05,  5.82215794e-04,  5.67803720e-03,
#         3.19406984e-05,  3.62007714e-04,  4.44934135e-03,  5.84306574e-02]), array([ 2.03419295e-04,  1.61631237e-04,  1.05378104e-04,  1.32240288e-03,
#        -1.85205343e-04,  1.00838564e-04,  9.40827554e-04,  5.67379352e-05,
#         6.79169977e-04,  8.72629455e-03, -5.25707179e-06, -2.05218684e-04,
#        -5.37725706e-04,  6.45355170e-05,  5.82182249e-04,  5.67770671e-03,
#         3.19374955e-05,  3.61971169e-04,  4.44888805e-03,  5.84246503e-02]), array([ 2.03384153e-04,  1.61613049e-04,  1.05360072e-04,  1.32217503e-03,
#        -1.85036602e-04,  1.00827854e-04,  9.40729915e-04,  5.67283311e-05,
#         6.79054169e-04,  8.72479442e-03, -5.32789456e-06, -2.05088348e-04,
#        -5.36774442e-04,  6.45290034e-05,  5.82126273e-04,  5.67715521e-03,
#         3.19321512e-05,  3.61910190e-04,  4.44813167e-03,  5.84146267e-02]), array([ 2.03325523e-04,  1.61582701e-04,  1.05329987e-04,  1.32179491e-03,
#        -1.84755094e-04,  1.00809985e-04,  9.40567002e-04,  5.67123078e-05,
#         6.78860955e-04,  8.72229163e-03, -5.44604055e-06, -2.04870912e-04,
#        -5.35187522e-04,  6.45181352e-05,  5.82032873e-04,  5.67623499e-03,
#         3.19232349e-05,  3.61808452e-04,  4.44686973e-03,  5.83979035e-02]), array([ 2.03227728e-04,  1.61532076e-04,  1.05279805e-04,  1.32116086e-03,
#        -1.84285582e-04,  1.00780176e-04,  9.40295224e-04,  5.66855807e-05,
#         6.78538675e-04,  8.71811698e-03, -5.64307081e-06, -2.04508262e-04,
#        -5.32540958e-04,  6.45000045e-05,  5.81877056e-04,  5.67469980e-03,
#         3.19083623e-05,  3.61638753e-04,  4.44476481e-03,  5.83700092e-02]), array([ 2.03064668e-04,  1.61447652e-04,  1.05196133e-04,  1.32010367e-03,
#        -1.83502862e-04,  1.00730462e-04,  9.39841965e-04,  5.66410168e-05,
#         6.78001315e-04,  8.71115631e-03, -5.97148841e-06, -2.03903689e-04,
#        -5.28129340e-04,  6.44697669e-05,  5.81617176e-04,  5.67213929e-03,
#         3.18835639e-05,  3.61355801e-04,  4.44125512e-03,  5.83234991e-02]), array([ 2.02792963e-04,  1.61306937e-04,  1.05056710e-04,  1.31834207e-03,
#        -1.82198960e-04,  1.00647597e-04,  9.39086397e-04,  5.65667591e-05,
#         6.77105904e-04,  8.69955773e-03, -6.51844385e-06, -2.02896553e-04,
#        -5.20781487e-04,  6.44193623e-05,  5.81183927e-04,  5.66787052e-03,
#         3.18422416e-05,  3.60884310e-04,  4.43540686e-03,  5.82459991e-02]), array([ 2.02340703e-04,  1.61072602e-04,  1.04824635e-04,  1.31540984e-03,
#        -1.80029537e-04,  1.00509588e-04,  9.37827894e-04,  5.64431523e-05,
#         6.75615445e-04,  8.68025144e-03, -7.42807086e-06, -2.01220881e-04,
#        -5.08559728e-04,  6.43354072e-05,  5.80462184e-04,  5.66075896e-03,
#         3.17734569e-05,  3.60099474e-04,  4.42567206e-03,  5.81169966e-02]), array([ 2.01589243e-04,  1.60682930e-04,  1.04439018e-04,  1.31053769e-03,
#        -1.76427528e-04,  1.00280058e-04,  9.35734462e-04,  5.62377619e-05,
#         6.73138862e-04,  8.64817213e-03, -8.93728092e-06, -1.98438652e-04,
#        -4.88277124e-04,  6.41957556e-05,  5.79261320e-04,  5.64892566e-03,
#         3.16591585e-05,  3.58795337e-04,  4.40949633e-03,  5.79026449e-02]), array([ 2.00344323e-04,  1.60036521e-04,  1.03800159e-04,  1.30246604e-03,
#        -1.70467528e-04,  9.98991997e-05,  9.32259860e-04,  5.58974740e-05,
#         6.69035772e-04,  8.59502591e-03, -1.14314450e-05, -1.93835028e-04,
#        -4.54744083e-04,  6.39639726e-05,  5.77267356e-04,  5.62927491e-03,
#         3.14697824e-05,  3.56634604e-04,  4.38269664e-03,  5.75475213e-02]), array([ 1.98292022e-04,  1.58968535e-04,  1.02746914e-04,  1.28915925e-03,
#        -1.60662528e-04,  9.92696734e-05,  9.26513967e-04,  5.53364280e-05,
#         6.62271060e-04,  8.50740811e-03, -1.55263516e-05, -1.86261270e-04,
#        -3.99652554e-04,  6.35806912e-05,  5.73967725e-04,  5.59675058e-03,
#         3.11575289e-05,  3.53071964e-04,  4.33851111e-03,  5.69620470e-02]), array([ 1.94936228e-04,  1.57215775e-04,  1.01024553e-04,  1.26739990e-03,
#        -1.44686005e-04,  9.82357452e-05,  9.17069695e-04,  5.44188554e-05,
#         6.51208177e-04,  8.36412970e-03, -2.21759201e-05, -1.73919835e-04,
#        -3.10089116e-04,  6.29507459e-05,  5.68538150e-04,  5.54321508e-03,
#         3.06467886e-05,  3.47244955e-04,  4.26624754e-03,  5.60046097e-02]), array([ 1.89522630e-04,  1.54370693e-04,  9.82455917e-05,  1.23229503e-03,
#        -1.19066053e-04,  9.65554193e-05,  9.01701578e-04,  5.29381192e-05,
#         6.33356997e-04,  8.13296144e-03, -3.27776081e-05, -1.54127298e-04,
#        -1.67014483e-04,  6.19257622e-05,  5.59686461e-04,  5.45589445e-03,
#         2.98224184e-05,  3.37840456e-04,  4.14963320e-03,  5.44597780e-02]), array([ 1.80981053e-04,  1.49835018e-04,  9.38597976e-05,  1.17690004e-03,
#        -7.90591722e-05,  9.38712016e-05,  8.77101531e-04,  5.06004915e-05,
#         6.05179695e-04,  7.76814484e-03, -4.91695734e-05, -1.23214053e-04,
#         5.49589839e-05,  6.02852404e-05,  5.45474137e-04,  5.31558267e-03,
#         2.85205651e-05,  3.22990638e-04,  3.96553874e-03,  5.20215939e-02]), array([ 1.67981938e-04,  1.42811306e-04,  8.71822825e-05,  1.09257995e-03,
#        -1.92822789e-05,  8.97007700e-05,  8.38755843e-04,  4.70395611e-05,
#         5.62267891e-04,  7.21274371e-03, -7.32432247e-05, -7.70027909e-05,
#         3.82960727e-04,  5.77283329e-05,  5.23211032e-04,  5.09553062e-03,
#         2.65363515e-05,  3.00362194e-04,  3.68511724e-03,  4.83091224e-02]), array([ 1.49306832e-04,  1.32421378e-04,  7.75819691e-05,  9.71403038e-04,
#         6.37378002e-05,  8.34984763e-05,  7.81441671e-04,  4.19155953e-05,
#         5.00547384e-04,  6.41435687e-03, -1.05655913e-04, -1.27458498e-05,
#         8.29746111e-04,  5.39064599e-05,  4.89674933e-04,  4.76351158e-03,
#         2.36785586e-05,  2.67783274e-04,  3.28164167e-03,  4.29711579e-02]), array([ 1.24761701e-04,  1.18078906e-04,  6.49483380e-05,  8.12054500e-04,
#         1.65869557e-04,  7.48643436e-05,  7.01080932e-04,  3.51629576e-05,
#         4.19270506e-04,  5.36401199e-03, -1.43220915e-04,  6.65686186e-05,
#         1.36029006e-03,  4.85445026e-05,  4.42094909e-04,  4.29154903e-03,
#         1.99066059e-05,  2.24810743e-04,  2.75002079e-03,  3.59458503e-02]), array([ 9.64127780e-05,  1.00113960e-04,  5.03266160e-05,  6.27862663e-04,
#         2.68261749e-04,  6.39135518e-05,  5.98239223e-04,  2.73290617e-05,
#         3.25104325e-04,  4.14908801e-03, -1.76181724e-04,  1.46921886e-04,
#         1.85560183e-03,  4.16670101e-05,  3.80181224e-04,  3.67658266e-03,
#         1.55195695e-05,  1.74888266e-04,  2.13355032e-03,  2.78147881e-02]), array([ 6.87121896e-05,  8.01725743e-05,  3.59921237e-05,  4.47678763e-04,
#         3.38476992e-04,  5.15552561e-05,  4.81210139e-04,  1.96201089e-05,
#         2.32651306e-04,  2.95947268e-03, -1.90210108e-04,  2.04332187e-04,
#         2.13452212e-03,  3.37939175e-05,  3.08255390e-04,  2.96309302e-03,
#         1.11853300e-05,  1.25666379e-04,  1.52755258e-03,  1.98463369e-02]), array([ 4.59834160e-05,  6.06394442e-05,  2.41754756e-05,  2.99649078e-04,
#         3.50724189e-04,  3.92320871e-05,  3.64195795e-04,  1.32317018e-05,
#         1.56312448e-04,  1.98113234e-03, -1.76878749e-04,  2.20060622e-04,
#         2.08268871e-03,  2.58280322e-05,  2.34829144e-04,  2.23954321e-03,
#         7.57380936e-06,  8.47874419e-05,  1.02650672e-03,  1.32869928e-02]), array([ 2.96056946e-05,  4.34645796e-05,  1.56153678e-05,  1.92894184e-04,
#         3.08925928e-04,  2.82390783e-05,  2.60424048e-04,  8.57645362e-06,
#         1.00950353e-04,  1.27511138e-03, -1.42224011e-04,  1.97057090e-04,
#         1.76181664e-03,  1.86434814e-05,  1.68670577e-04,  1.59558996e-03,
#         4.92612597e-06,  5.49533149e-05,  6.62825014e-04,  8.55062022e-03]), array([ 1.86014624e-05,  2.96733620e-05,  9.83605560e-06,  1.21157856e-04,
#         2.40170509e-04,  1.93307602e-05,  1.77228267e-04,  5.41688915e-06,
#         6.35656116e-05,  8.00664246e-04, -1.00270955e-04,  1.54379019e-04,
#         1.33460282e-03,  1.27839362e-05,  1.15112390e-04,  1.08157524e-03,
#         3.11958323e-06,  3.46966306e-05,  4.17217303e-04,  5.36764630e-03])]

# %%
from math import log10

maping = list(map(log10, w3_reg[0]))
plt.plot(maping, w3_reg[1])
plt.plot(maping, w3_reg[2])
plt.legend(["Train", "Test"])
plt.xlabel("Log(lambda)")
plt.ylabel("Error")
plt.show()

# %%
def k_fold_cross(X, Y):
    Kfold= 10
    sets_length = int(len(X) / Kfold)
    
    models_tra = []
    models_tes = []
    lambdas = []
    for i in range(Kfold):
        x_train = X[np.r_[0:i * sets_length, (i + 1) * sets_length:len(X)], :]
        y_train = Y[np.r_[0:i * sets_length, (i + 1) * sets_length:len(X)]]
        x_test = X[i * sets_length : (i + 1) * sets_length, :]
        y_test = Y[i * sets_length : (i + 1) * sets_length]
        model = third_reg_regu(x_train, y_train, x_test, y_test)
        models_tra.append(model[1])
        models_tes.append(model[2])
        lambdas = model[0]
    return (lambdas, models_tra, models_tes)

# %%
models = k_fold_cross(X, Y)

# %% [markdown]
#  For determine the best λ we implement k-fold cross validation. Then by using 10-fold cross validation will plot the error on train and test data based on different λ values and then report the best λ.

# %%
argmin = min(map(min,models[2]))
for i in range(len(models[2])):
    for j in range(len(models[2][0])):
        if models[2][i][j] == argmin:
            print(w3_reg[0][j])
            break
# Out:
# 0.36787944117144233

# %%
maping = list(map(log10, models[0]))
plt.plot(maping, np.array(models[1]).mean(axis = 0))
plt.plot(maping, np.array(models[2]).mean(axis = 0))
plt.legend(["Train", "Test"])
plt.xlabel("Log(lambda)")
plt.ylabel("Error")
plt.show()
